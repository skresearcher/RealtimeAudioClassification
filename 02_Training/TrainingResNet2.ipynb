# %% [markdown]
# ## Load libraries

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import time
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision
import os
from sklearn.metrics import confusion_matrix
import pickle
import os.path
from ipywidgets import interact, widgets
from IPython.display import Image, display, HTML
import glob

# %% [markdown]
# ## Define training and test sets

# %%
def listdir_nohidden(path):
    return glob.glob(os.path.join(path, '*'))
style = {'description_width': 'initial'}

# %%
SPECTRUM_IMAGES_ROOT='../GeneratedData/'
SPECTRUM_IMAGES_CLASSESDropdown= widgets.Dropdown(options=listdir_nohidden(SPECTRUM_IMAGES_ROOT), description='Source for Training Data:',style=style)

display(SPECTRUM_IMAGES_CLASSESDropdown)
# Out:
# Dropdown(description='Source for Training Data:', options=('../GeneratedData/Cats-Vs-Dogs', '../GeneratedData/…

# %% [markdown]
# ## Loading data set
# If test set is not defined previously, this function pulls a test set from the training set using a 80/20%split

# %%
SPECTRUM_IMAGES_CLASSES_TRAIN = SPECTRUM_IMAGES_CLASSESDropdown.value
SPECTRUM_IMAGES_CLASSES_TEST = ''
INPUT_RESOLUTION = 224
    
transform = transforms.Compose(
    [transforms.Resize(INPUT_RESOLUTION),
    transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset=[]
testset=[]
NoTestSet=False
full_dataset=None
if len(SPECTRUM_IMAGES_CLASSES_TEST)==0:
    print("Using one data set and separating them with an 80%/20% split")
    full_dataset = torchvision.datasets.ImageFolder(root=SPECTRUM_IMAGES_CLASSES_TRAIN, transform=transform)
    full_DataLoader = torch.utils.data.DataLoader(full_dataset, batch_size=4, shuffle=True, num_workers=2)
    train_size = int(0.8 * len(full_dataset))
    test_size = len(full_dataset) - train_size
    trainset, testset = torch.utils.data.random_split(full_dataset, [train_size, test_size])
    NoTestSet=True
else:
    print("Using pre-seperated test and training data sets!")
    trainset = torchvision.datasets.ImageFolder(root=SPECTRUM_IMAGES_CLASSES_TRAIN, transform=transform)
    testset = torchvision.datasets.ImageFolder(root=SPECTRUM_IMAGES_CLASSES_TEST, transform=transform)
    

trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=16, shuffle=False, num_workers=2)
classes=None
if(NoTestSet):
    classes = full_DataLoader.dataset.classes
else:
    classes = trainloader.dataset.classes

print(classes)
# Out:
# Using one data set and separating them with an 80%/20% split
# ['data']

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# ## Preview sample training images

# %% [markdown]
# The following cell takes an entire training batch of images and displays them with their respective labels. Have a look and verify that indeed you see spectrograph images that look similar to what you saw earlier.

# %%
#Getting some random training images and showing them
dataiter = iter(trainloader)
images, labels = dataiter.next()
for i in range(trainloader.batch_size):
    imshow(images[i])
    print(classes[labels[i]])
# Out:
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data

# %% [markdown]
# ## Specify use of Graphics Card (if there is one) and use ResNet

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = models.resnet18(pretrained=False)

# %% [markdown]
# ## Load pretrained model
# The model '../Models/MainModelUrban.pth' was trained on the UrbanSound dataset; other models could be specified instead.

# %%
ModelData = torch.load('../Models/MainModelUrban.pth',map_location='cpu')
model.load_state_dict(ModelData['model'])
# IncompatibleKeys(missing_keys=[], unexpected_keys=[]) Means it was succesfull
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %% [markdown]
# ## Cutting off the head
# In the following cell, the setting 'param.requires_grad = False' is **the** function that is telling the network to only retrain the last layer. If you set this parameter to True, the training will take much longer, but hopefully be better at predicting.

# %%
for param in model.parameters():
    param.requires_grad = False
model.fc = nn.Linear(512, len(classes)) # otherwise change it

# %% [markdown]
# ## Move model to GPU (if there is a GPU)

# %%
print('device is', device)
if device.type=='cuda':
    model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
train_epoch_losses=[]
test_epoch_losses=[]
epoch=0
# Out:
# device is cpu

# %% [markdown]
# ## Training the network

# %%
#Training the network on the training dataset
for i in range(5):  # loop over the dataset multiple (5) times 
    epoch+=1
    print("Starting epoch:",epoch)
    epochLoss=0.0
    t0 = time.time()
    model.train()
    for i, data in enumerate(trainloader, 0):
        #print("Running Batches",i)
        # get the inputs
        inputs, labels = data
        if device.type=='cuda':
            inputs, labels = inputs.to(device), labels.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        if((i+i)%200==0):
            if(i>0):
                print('Processed images:',i*trainloader.batch_size,'. Running Timer @ {:.2f}sec.'.format(time.time()-t0))
        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epochLoss+=loss.item()
        #break;
    
    model.eval()
    testLoss=0
    print("About to test the performance on the test set.")
    with torch.no_grad():
        for i, data in enumerate(testloader, 0):
            # get the inputs
            inputs, labels = data
            if device.type=='cuda':
                inputs, labels = inputs.to(device), labels.to(device)
            # forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            testLoss+=loss.item()
            if(i%50==0):
                if(i>0):
                    print('Tested images:',i*testloader.batch_size,'. Running Timer @ {:.2f}sec.'.format(time.time()-t0))


    train_epoch_losses.append(epochLoss/len(trainloader))
    test_epoch_losses.append(testLoss/len(testloader))
    EpochLength = time.time()-t0
    print('{} train loss: {:.3f} and test loss: {:.3f}, and it took us: {:.2f} seconds.'.format (epoch + 1, epochLoss / len(trainloader),testLoss/len(testloader),EpochLength))  # DAVID CHanged it to 1000 from 2000 not sure if thats totally done

print('Finished Training')
# Out:
# Starting epoch: 1
# Processed images: 1600 . Running Timer @ 112.55sec.
# Processed images: 3200 . Running Timer @ 224.68sec.
# Processed images: 4800 . Running Timer @ 337.60sec.
# Processed images: 6400 . Running Timer @ 450.48sec.
# Processed images: 8000 . Running Timer @ 562.63sec.
# Processed images: 9600 . Running Timer @ 674.21sec.
# Processed images: 11200 . Running Timer @ 786.60sec.
# Processed images: 12800 . Running Timer @ 903.69sec.
# Processed images: 14400 . Running Timer @ 1026.78sec.
# Processed images: 16000 . Running Timer @ 1151.44sec.
# Processed images: 17600 . Running Timer @ 1283.33sec.
# Processed images: 19200 . Running Timer @ 1405.45sec.
# Processed images: 20800 . Running Timer @ 1523.11sec.
# Processed images: 22400 . Running Timer @ 1638.30sec.
# Processed images: 24000 . Running Timer @ 1761.68sec.
# Processed images: 25600 . Running Timer @ 1890.54sec.
# Processed images: 27200 . Running Timer @ 2016.77sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 2068.42sec.
# Tested images: 1600 . Running Timer @ 2113.95sec.
# Tested images: 2400 . Running Timer @ 2161.68sec.
# Tested images: 3200 . Running Timer @ 2208.37sec.
# Tested images: 4000 . Running Timer @ 2256.07sec.
# Tested images: 4800 . Running Timer @ 2300.29sec.
# Tested images: 5600 . Running Timer @ 2345.12sec.
# Tested images: 6400 . Running Timer @ 2393.82sec.
# 2 train loss: 0.000 and test loss: 0.000, and it took us: 2416.04 seconds.
# Starting epoch: 2
# Processed images: 1600 . Running Timer @ 120.39sec.
# Processed images: 3200 . Running Timer @ 244.40sec.
# Processed images: 4800 . Running Timer @ 370.69sec.
# Processed images: 6400 . Running Timer @ 496.44sec.
# Processed images: 8000 . Running Timer @ 621.41sec.
# Processed images: 9600 . Running Timer @ 745.89sec.
# Processed images: 11200 . Running Timer @ 865.90sec.
# Processed images: 12800 . Running Timer @ 985.13sec.
# Processed images: 14400 . Running Timer @ 1101.91sec.
# Processed images: 16000 . Running Timer @ 1217.62sec.
# Processed images: 17600 . Running Timer @ 1334.38sec.
# Processed images: 19200 . Running Timer @ 1461.63sec.
# Processed images: 20800 . Running Timer @ 1589.69sec.
# Processed images: 22400 . Running Timer @ 1717.62sec.
# Processed images: 24000 . Running Timer @ 1845.61sec.
# Processed images: 25600 . Running Timer @ 1973.33sec.
# Processed images: 27200 . Running Timer @ 2100.85sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 2154.63sec.
# Tested images: 1600 . Running Timer @ 2204.33sec.
# Tested images: 2400 . Running Timer @ 2256.48sec.
# Tested images: 3200 . Running Timer @ 2306.26sec.
# Tested images: 4000 . Running Timer @ 2357.35sec.
# Tested images: 4800 . Running Timer @ 2408.24sec.
# Tested images: 5600 . Running Timer @ 2458.09sec.
# Tested images: 6400 . Running Timer @ 2510.27sec.
# 3 train loss: 0.000 and test loss: 0.000, and it took us: 2534.51 seconds.
# Starting epoch: 3
# Processed images: 1600 . Running Timer @ 127.80sec.
# Processed images: 3200 . Running Timer @ 255.64sec.
# Processed images: 4800 . Running Timer @ 383.46sec.
# Processed images: 6400 . Running Timer @ 512.66sec.
# Processed images: 8000 . Running Timer @ 641.97sec.
# Processed images: 9600 . Running Timer @ 769.83sec.
# Processed images: 11200 . Running Timer @ 897.27sec.
# Processed images: 12800 . Running Timer @ 1024.28sec.
# Processed images: 14400 . Running Timer @ 1151.81sec.
# Processed images: 16000 . Running Timer @ 1279.59sec.
# Processed images: 17600 . Running Timer @ 1407.48sec.
# Processed images: 19200 . Running Timer @ 1535.06sec.
# Processed images: 20800 . Running Timer @ 1664.89sec.
# Processed images: 22400 . Running Timer @ 1793.71sec.
# Processed images: 24000 . Running Timer @ 1921.35sec.
# Processed images: 25600 . Running Timer @ 2048.71sec.
# Processed images: 27200 . Running Timer @ 2176.14sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 2227.66sec.
# Tested images: 1600 . Running Timer @ 2279.74sec.
# Tested images: 2400 . Running Timer @ 2329.66sec.
# Tested images: 3200 . Running Timer @ 2382.97sec.
# Tested images: 4000 . Running Timer @ 2432.46sec.
# Tested images: 4800 . Running Timer @ 2484.46sec.
# Tested images: 5600 . Running Timer @ 2534.06sec.
# Tested images: 6400 . Running Timer @ 2584.47sec.
# 4 train loss: 0.000 and test loss: 0.000, and it took us: 2609.97 seconds.
# Starting epoch: 4
# Processed images: 1600 . Running Timer @ 127.48sec.
# Processed images: 3200 . Running Timer @ 255.13sec.
# Processed images: 4800 . Running Timer @ 383.12sec.
# Processed images: 6400 . Running Timer @ 510.83sec.
# Processed images: 8000 . Running Timer @ 638.74sec.
# Processed images: 9600 . Running Timer @ 766.78sec.
# Processed images: 11200 . Running Timer @ 896.26sec.
# Processed images: 12800 . Running Timer @ 1026.80sec.
# Processed images: 14400 . Running Timer @ 1155.17sec.
# Processed images: 16000 . Running Timer @ 1281.56sec.
# Processed images: 17600 . Running Timer @ 1399.41sec.
# Processed images: 19200 . Running Timer @ 1525.44sec.
# Processed images: 20800 . Running Timer @ 1647.50sec.
# Processed images: 22400 . Running Timer @ 1763.76sec.
# Processed images: 24000 . Running Timer @ 1885.43sec.
# Processed images: 25600 . Running Timer @ 2004.02sec.
# Processed images: 27200 . Running Timer @ 2120.60sec.
# About to test the performance on the test set.
# Tested images: 800 . Running Timer @ 2168.46sec.
# Tested images: 1600 . Running Timer @ 2213.12sec.
# Tested images: 2400 . Running Timer @ 2260.42sec.
# Tested images: 3200 . Running Timer @ 2316.67sec.
# Tested images: 4000 . Running Timer @ 2361.62sec.
# Tested images: 4800 . Running Timer @ 2409.41sec.
# Tested images: 5600 . Running Timer @ 2451.76sec.
# Tested images: 6400 . Running Timer @ 2494.72sec.
# 5 train loss: 0.000 and test loss: 0.000, and it took us: 2520.00 seconds.
# Starting epoch: 5
# Processed images: 1600 . Running Timer @ 113.15sec.
# Processed images: 3200 . Running Timer @ 234.44sec.
# Processed images: 4800 . Running Timer @ 355.59sec.
# Processed images: 6400 . Running Timer @ 474.44sec.
# Processed images: 8000 . Running Timer @ 595.19sec.
# Processed images: 9600 . Running Timer @ 719.26sec.
# Processed images: 11200 . Running Timer @ 848.68sec.
# Processed images: 12800 . Running Timer @ 974.77sec.
# Processed images: 14400 . Running Timer @ 1099.88sec.
# Processed images: 16000 . Running Timer @ 1222.29sec.
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7dd32be5b4f6> in <module>
#      19                 print('Processed images:',i*trainloader.batch_size,'. Running Timer @ {:.2f}sec.'.format(time.time()-t0))
#      20         # forward + backward + optimize
# ---> 21         outputs = model(inputs)
#      22         loss = criterion(outputs, labels)
#      23         loss.backward()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     191     def forward(self, x):
#     192         x = self.conv1(x)
# --> 193         x = self.bn1(x)
#     194         x = self.relu(x)
#     195         x = self.maxpool(x)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      81             input, self.running_mean, self.running_var, self.weight, self.bias,
#      82             self.training or not self.track_running_stats,
# ---> 83             exponential_average_factor, self.eps)
#      84
#      85     def extra_repr(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1695     return torch.batch_norm(
#    1696         input, weight, bias, running_mean, running_var,
# -> 1697         training, momentum, eps, torch.backends.cudnn.enabled
#    1698     )
#    1699
#
# KeyboardInterrupt:

# %% [markdown]
# ## Post training analytics

# %% [markdown]
# After the training has finished, save information about the training

# %%
# saving the learnd model in file that can be loaded in for inference
SpectrumVariables = pickle.load(open(os.path.join(SPECTRUM_IMAGES_CLASSES_TRAIN,'Main.SpecVar'), "rb" ) )
torch.save({
    'model':model.state_dict(),
    'classes':classes,
    'resolution':INPUT_RESOLUTION,
    'SpectrumVariables':SpectrumVariables,
    'modelType':"resnet18" # <= If you try out different models make sure to change this too
},"../models/CatDogResNet.pth") # <=Edit file name here

# %% [markdown]
# Display how the traing and test loss progressed over successive epochs

# %%
#Displaying how the loss progresses over time.
plt.plot(train_epoch_losses, label='Training Loss',c='r')
plt.plot(test_epoch_losses, label='Test Loss',c='g')
plt.legend()
plt.show()

# %% [markdown]
# Show spectagrams, Predicted and Actual labels.

# %%
# Print predicted and acual labels for Spectragrams
dataiter = iter(testloader)
model.eval()
for j in range (2):
    images, labels = dataiter.next()
    if device == 'cuda':
        images, labels = images.to(device), labels.to(device)
    outputs = model(images)
    _, predicted = torch.max(outputs, 1)

    for i in range(len(images)):
        imshow(images[i])
        print('GroundTruth: ',classes[labels[i]])
        print('Predicted: ',  classes[predicted[i]])

# %% [markdown]
# Print accuracy of test predictions for each label

# %%
# Network analytics
class_correct = list(0. for i in range(len(classes)))
class_total = list(0. for i in range(len(classes)))
model.eval()
allLabels=[]
allPrediction=[]
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        if (c.dim()==0):
            continue
        for i in range(testloader.batch_size):
            if(len(labels)<=i):
                continue;
            label = labels[i]
            allLabels.append(labels[i].to('cpu').numpy())
            allPrediction.append(predicted[i].to('cpu').numpy())
            #print (c.shape)
            if(testloader.batch_size>1):

                class_correct[label] += c[i].item()
            else:
                class_correct[label] += c.item()
            class_total[label] += 1

print(confusion_matrix(allLabels, allPrediction))
for i in range(len(classes)):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
